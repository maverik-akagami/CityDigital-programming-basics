# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rtu = pd.read_csv('RTU.csv')
rtu = rtu.ffill()

# %%
pd.Series.unique(rtu['Column3'])
# Out:
# array(['0', 'TIME (0)', 'TIME (1)', '10', '41', '45', '46', '48', '49',
#        '47', '18', '40', '42', '43', '17', '29', '15', '16', '44', '31',
#        '50', '13', '30', '34', '35', '37', '38', '28', '12', '25', '23',
#        '27', '32', '33', '26', '11', '39', '21', '22', '24', '19', '36',
#        '14', '51', '64', '20', '60', '59', '52', 'TIME (21)', 'TIME (-19)',
#        'TIME (-20)', 'TIME (-21)', 'TIME (22)', 'TIME (23)', 'TIME (-22)',
#        '68', '73', '66', '62', '71', '53', '63', '58', '72', 'TIME (-23)',
#        'TIME (24)', 'TIME (25)', 'TIME (-24)', 'TIME (26)', 'TIME (-25)',
#        '100', '93', '99', '89', '61', 'TIME (-26)', 'TIME (27)',
#        'TIME (3601)', '74', '55', '70', '54', 'TIME (-28)', 'TIME (29)',
#        'TIME (-27)', 'TIME (28)', '56', 'TIME (30)', 'TIME (-29)',
#        'TIME (31)', '90', 'TIME (-30)', '97', '83', 'TIME (-31)',
#        'TIME (32)', '65', 'TIME (-32)', 'TIME (33)', '57', 'TIME (-33)',
# ...

# %%
df1 = rtu.copy()

# %%
rtu.rename(columns={'Column1': 'Date', 'Column2': 'Time', 'Column3': 'Economiser position %', 'Column4':'DX coil ON?OFF'}, inplace = True)
rtu.rename(columns={'Column5': 'DX coil ON?OFF', 'Column6': 'Supplier Temperature', 'Column7': 'supply fan ON?OFF'}, inplace = True)
rtu.rename(columns={'Column8': 'heating coil ON?OFF', 'Column9': 'Room Temperature'},inplace = True)

# %%
rtu.head()
# Out:
#          Date      Time Economiser position % DX coil ON?OFF DX coil ON?OFF  \
# 0  31-12-2015  00:00:00                     0            OFF            OFF
# 1  31-12-2015  00:00:00                     0            OFF            OFF
# 2  31-12-2015  00:15:00                     0            OFF            OFF
# 3  31-12-2015  00:30:00                     0            OFF            OFF
# 4  31-12-2015  00:45:00                     0            OFF            OFF
#
#   Supplier Temperature supply fan ON?OFF heating coil ON?OFF Room Temperature
# 0                 59.5               OFF                 OFF             80.1
# 1                 60.4               OFF                 OFF             80.2
# 2                   61               OFF                 OFF             80.4
# 3                 61.1               OFF                 OFF             80.4
# 4                 61.2               OFF                 OFF             80.4

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data = [rtu['Supplier Temperature'], rtu['Room Temperature']]
print list(rtu.columns.values)
#plt.boxplot(data)
#plt.show()
print rtu['Economiser position %'].unique()
print rtu['Supplier Temperature'].unique()
print  rtu['Room Temperature'].unique()
# Out:
# ['Date', 'Time', 'Economiser position %', 'DX coil ON?OFF', 'DX coil ON?OFF', 'Supplier Temperature', 'supply fan ON?OFF', 'heating coil ON?OFF', 'Room Temperature']
# ['0' 'TIME (0)' 'TIME (1)' '10' '41' '45' '46' '48' '49' '47' '18' '40'
#  '42' '43' '17' '29' '15' '16' '44' '31' '50' '13' '30' '34' '35' '37' '38'
#  '28' '12' '25' '23' '27' '32' '33' '26' '11' '39' '21' '22' '24' '19' '36'
#  '14' '51' '64' '20' '60' '59' '52' 'TIME (21)' 'TIME (-19)' 'TIME (-20)'
#  'TIME (-21)' 'TIME (22)' 'TIME (23)' 'TIME (-22)' '68' '73' '66' '62' '71'
#  '53' '63' '58' '72' 'TIME (-23)' 'TIME (24)' 'TIME (25)' 'TIME (-24)'
#  'TIME (26)' 'TIME (-25)' '100' '93' '99' '89' '61' 'TIME (-26)'
#  'TIME (27)' 'TIME (3601)' '74' '55' '70' '54' 'TIME (-28)' 'TIME (29)'
#  'TIME (-27)' 'TIME (28)' '56' 'TIME (30)' 'TIME (-29)' 'TIME (31)' '90'
#  'TIME (-30)' '97' '83' 'TIME (-31)' 'TIME (32)' '65' 'TIME (-32)'
#  'TIME (33)' '57' 'TIME (-33)' 'TIME (34)' '81' '86' '91' '75' '82' '67'
# ...
