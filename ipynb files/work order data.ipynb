# %%
import openpyxl
work_order = openpyxl.load_workbook('IIT Work Order Samples (1).xlsm')
print type(work_order)
print work_order.get_sheet_names()
sheet_wo = work_order.get_sheet_by_name('Sheet 1')
print sheet_wo.title
# Out:
# <class 'openpyxl.workbook.workbook.Workbook'>
# [u'Sheet 1']
# Sheet 1

# %%
import pandas as pd
import numpy as np
wo = pd.read_excel('IIT Work Order Samples (1).xlsm')# creating a dataframe from the excel file
wo_fin = pd.read_excel('IIT Work Orders 2015_Present.xls')
wo_des = wo['Description.1'] # considering only the description of the workd orders
wo.fillna('missing')
wo_fin.head()
#wo_it = wo_fin[wo_fin['Building'].str.contains('IT')]
wo_it_des = wo_it['Description']
wo_it['Floor'] = wo_it['Floor'].replace('n/a', np.NaN)

# %%
wo_it.Floor.isnull().sum()
wo_count = pd.DataFrame(wo_it['Floor'].value_counts(dropna = False))
wo_count.columns.values
# Out:
# array([u'Floor'], dtype=object)

# %%
import numpy as np
import matplotlib.pyplot as plt
#wo_it['Floor'] = wo_it['Floor'].fillna(25)
u, count = np.unique(wo_it['Floor'], return_index = True)
#plt.bar(count, u, align='center',alpha = 0.5)
#df10 = pd.DataFrame({'Floor':u, 'Count': count})
#print df10.sort(['Floor','Count'], ascending=[1,0])
#plt.bar(df10['Floor'],df10['Count'],align='center',alpha = 0.4)
#wo_it['Floor'] = wo_it['Floor'].dropna()
#wo_it.Floor.hist()
#wo_it.Floor.value_counts(dropna =False).hist()
#plt.show()
wo_it.head()
# Out:
#    Wo Number                           Description Assigned To Building Floor  \
# 12  WO121611                 [ROOM, IS, TOO, COLD]    TJABCZYN       IT    13
# 19  WO121617  [CAR, 2, IS, STUCK, ON, 19TH, FLOOR]    MCUSACK1       IT   NaN
# 29  WO121631                 [ROOM, IS, TOO, COLD]    TJABCZYN       IT    13
# 33  WO121627                     [ROOM, TOO, COLD]    TARIANOU       IT     3
# 39  WO121648                      [REPAIR, TOILET]    TARIANOU       IT     2
#
#         Room     Craft          Enter Date       Wo Close Date  Hours SUM
# 12    13F3-2      HVAC 2015-01-05 08:52:36 2015-01-06 14:54:47       1.00
# 19       n/a  ELEVATOR 2015-01-05 09:57:08 2015-01-30 09:09:12        NaN
# 29    13F7-2      HVAC 2015-01-05 10:25:53 2015-01-06 14:55:23       1.50
# 33     3C7-1      HVAC 2015-01-05 10:43:31 2015-01-05 15:38:34       0.75
# 39  WR-02-00  PLUMBING 2015-01-05 11:56:19 2015-01-07 15:33:06       1.25

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
import numpy
from collections import Counter
from nltk.corpus import stopwords
import nltk
result = Counter(" ".join(wo_it['Description'].astype(str)).split(" ")).most_common(220)
df_res = pd.DataFrame(result)
df_res.to_excel('wordfreq.xlsx')
#print df_res[0]
#stop = set(stopwords.words('english'))
#stopwordsfree_words = [word for word in result if word not in stop]
#fd = nltk.FreqDist(wo_it['Description'].astype(str))
#print fd.tabulate()

# %%
#wo_it['Description'] = wo_it['Description'].str.split(" ")
import string
wo_it['Description'][62] = wo_it[]
#wo_it['Description'] = wo_it['Description'].translate(None, string.punctuation.translate(None, '"'))
#wo_it['Description'].apply(lambda x:[item for item in x if item not in stop])
# Out:
#   File "<ipython-input-47-4d692fa4ee72>", line 3
#     wo_it['Description'][62] = wo_it[]
#                                      ^
# SyntaxError: invalid syntax

# %%
s = wo_it.groupby("Floor").Floor.agg(lambda x:len(x.unique()))
pd.value_counts(s).plot(kind="bar")
plt.show()

# %%
from collections import Counter
counts = Counter(wo_it_des)
count = counts.most_common()
#for i in xrange(0,14): print counts[i]
#print(count) 
countdf = pd.DataFrame(count)
#print countdf
freq_desc = pd.ExcelWriter('freq_desc_it.xlsx', engine = 'xlsxwriter')
#countdf.to_excel(freq_desc, sheet_name = 'Frequency of Description')
writer = pd.ExcelWriter('iitresearchtower.xlsx', engine = 'xlsxwriter')
df2 = wo_it
df2.to_excel(writer, sheet_name = 'IIT')

# %%
def keyword(str):
    df = wo_it[wo_it_des.str.contains(str, na = False)]
    df.to_excel(writer, sheet_name = str)


writer = pd.ExcelWriter('keyword_it.xlsx', engine = 'xlsxwriter')
keyword("HVAC")
keyword("AHU")
keyword("FILTER")
keyword("FAN")
keyword("COIL")
keyword("TOO HOT")
keyword("TOO COLD")
keyword("OVERHEATING")
keyword("HEATING")
keyword("COOLING")
keyword("TEMPERATURE")
keyword("CHILLER")
keyword("BOILER")
keyword("DAMPER")
keyword("STEAM")
keyword("COLD")
keyword("REPAIR")
keyword("BASEMENT")
keyword("SUPPLY")
keyword("FIRE")
keyword("20TH")
keyword("19TH")
keyword("18TH")
keyword("17TH")
keyword("16TH")
keyword("15TH")
keyword("URGENT")
keyword("GOLF")
keyword("2")
keyword("4TH")
keyword("NOISE")
keyword("ROOM")
keyword("BULB")
keyword("LEAKING")
#keyword("A/C")
df = wo_it[wo_it_des.str.contains('A/C', na = False)]
df.to_excel(writer, sheet_name = 'Air_Cond')

# %%
wo_it[wo_it_des.str.contains("HVAC", na = False)]
#word_hvac.to_excel(writer, sheet_name = 'HVAC')
# Out:
#       Wo Number                            Description Assigned To Building  \
# 2795   WO124409                       REPAIR HVAC UNIT    TJABCZYN       IT
# 8823   WO130430                       REPAIR HVAC UNIT    TJABCZYN       IT
# 12572  WO134195                  REPAIR HVAC UNIT-ASAP    MCARMOD1       IT
# 15405  WO137035   REPAIR HVAC UNIT - BAD FOR EQUIPMENT    TARIANOU       IT
# 21201  WO142836                  HVAC SERVICE IN BD4-1    TJABCZYN       IT
# 24668  WO146303  REPAIR VARIOUS HVAC DUCT WORK - KIRBY    CDEBRIZZ       IT
# 25406  WO147041                                   HVAC    TJABCZYN       IT
#
#       Floor    Room       Craft          Enter Date       Wo Close Date  \
# 2795     11     n/a  MECHANICAL 2015-02-24 10:06:18 2015-02-27 12:50:31
# 8823      9   9C5-1  MECHANICAL 2015-06-30 11:48:05 2015-07-13 14:59:25
# 12572    16     n/a  HVAC EQUIP 2015-09-10 09:28:24 2015-09-11 16:01:31
# ...

# %%
wo[wo_des.str.contains("AHU", na = False)]
#word_ahu.to_excel(writer, sheet_name = 'AHU')
# Out:
#     WO Number          Description Building Floor Room       Craft  \
# 248  WO147137  INCUBATOR - CENTRAL     ER-C    01  n/a  HVAC EQUIP
#
#                                 Description.1          Enter Date  \
# 248  ORDER FILTERS FOR AHUS IN ERB AND METALS 2016-05-20 11:21:11
#
#          Requestor Assigned To  Labor
# 248  CARMODY, MIKE    JBOOKER2    3.5

# %%
 wo[wo_des.str.contains("FILTER", na = False)]
#word_filter.to_excel(writer, sheet_name = 'FILTER')
# Out:
#     WO Number                          Description Building Floor Room  \
# 158  WO146604  LIFE SCIENCES RESEARCH - 35 W. 34TH       LR   n/a  n/a
# 175  WO146521   KAPPA PHI DELTA - 3330 S. MICHIGAN       KP     3  311
# 214  WO146522   KAPPA PHI DELTA - 3330 S. MICHIGAN       KP     2  204
# 248  WO147137                  INCUBATOR - CENTRAL     ER-C    01  n/a
# 336  WO146836           CROWN HALL - 3360 S. STATE       CR   n/a  n/a
# 367  WO146845   GALVIN LIBRARY - 35 W. 33RD STREET       GL     1  n/a
# 467  WO146839    TECH PARK - NORTH - 3410 S. STATE       TN   n/a  n/a
#
#           Craft                                      Description.1  \
# 158        HVAC                    REPLACE FAN FILTERS (BI-WEEKLY)
# 175  HVAC EQUIP  KPD 311: MOLD IN AIR CONDITIONER/FILTER NEEDS ...
# 214  HVAC EQUIP  KPD 204: MOLD IN AIR CONDITIONER/FILTERS NEEDS...
# 248  HVAC EQUIP           ORDER FILTERS FOR AHUS IN ERB AND METALS
# ...

# %%
wo[wo_des.str.contains("FAN", na = False)]
#word_fan.to_excel(writer, sheet_name = 'FAN')
# Out:
#     WO Number                          Description Building Floor  Room  \
# 158  WO146604  LIFE SCIENCES RESEARCH - 35 W. 34TH       LR   n/a   n/a
# 249  WO147390       HERMANN HALL - 3241 S. FEDERAL       HH   n/a   n/a
# 409  WO146977  MCCORMICK STUDENT VL. 3241 S WABASH       MS   n/a   n/a
# 455  WO147353                    INCUBATOR - SOUTH     ER-S    01   n/a
# 629  WO147081  MCCORM. TRIB. C. C. - 3201 S. STATE       MC   n/a   n/a
# 673  WO146473       HERMANN HALL - 3241 S. FEDERAL       HH     1   n/a
# 678  WO146930      IIT RESEARCH TOWER - 10 W. 35TH       IT   n/a   n/a
# 723  WO146605  LIFE SCIENCES RESEARCH - 35 W. 34TH       LR   n/a   n/a
# 880  WO147781        KEATING HALL - 3040 S. WABASH       KH     2    25
# 886  WO146295  MCCORMICK STUDENT VL. 3241 S WABASH       MS     1  100A
# 931  WO147415                    INCUBATOR - SOUTH     ER-S   n/a   n/a
#
#           Craft                                      Description.1  \
# ...

# %%
wo[wo_des.str.contains("COIL", na = False)]
#word_coil.to_excel(writer, sheet_name = 'COIL')
# Out:
#     WO Number                          Description Building Floor  Room  \
# 66   WO147070     LIFE SCIENCES - 3105 S. DEARBORN       LS   n/a   n/a
# 629  WO147081  MCCORM. TRIB. C. C. - 3201 S. STATE       MC   n/a   n/a
# 774  WO147413      IIT RESEARCH TOWER - 10 W. 35TH       IT    15   n/a
# 886  WO146295  MCCORMICK STUDENT VL. 3241 S WABASH       MS     1  100A
#
#           Craft                                      Description.1  \
# 66        OTHER                        LS: REPAIR CHILL WATER COIL
# 629       OTHER                          MC: LOCATE FAN COIL UNITS
# 774  HVAC EQUIP  CLEAN COILS ON ALL CONVECTORS  15TH FLOOR IIT ...
# 886  HVAC EQUIP                                    PM THE FAN COIL
#
#              Enter Date        Requestor Assigned To  Labor
# 66  2016-05-18 16:11:57     NAVA, JAVIER      JNAVA2   3.25
# 629 2016-05-19 08:52:06  KIRSHNER, TRACY    TKIRSHNE   3.50
# 774 2016-05-27 09:22:01    CARMODY, MIKE     NOEHMEN  21.75
# ...

# %%
wo[wo_des.str.contains("TOO HOT", na = False)]
#word_too_hot.to_excel(writer, sheet_name = 'TOO HOT')
# Out:
#     WO Number                          Description Building Floor       Room  \
# 38   WO147366       SIEGEL HALL - 3301 S. DEARBORN       SH     2        216
# 183  WO146810  MCCORMICK STUDENT VL. 3241 S WABASH       MS     1        n/a
# 188  WO146748  LIFE SCIENCES RESEARCH - 35 W. 34TH       LR     2      2C4-2
# 211  WO147339    RETTALIATA ENG CTR - 10 WEST 32ND       E1   n/a        n/a
# 307  WO146754    TECH PARK - SOUTH - 3440 S. STATE       TS     4  4026/4027
# 407  WO146271   KAPPA PHI DELTA - 3330 S. MICHIGAN       KP   n/a        n/a
# 479  WO147288    RETTALIATA ENG CTR - 10 WEST 32ND       E1   n/a        n/a
# 515  WO147276          PERLSTEIN HALL - 10 W. 33RD       PH   n/a        n/a
# 516  WO147286         VANDERCOOK - 3140 S. FEDERAL       VA     1        104
# 739  WO147332    TECH PARK - SOUTH - 3440 S. STATE       TS     2       2035
# 759  WO147139                    INCUBATOR - SOUTH     ER-S    02     220S-1
# ...

# %%
wo[wo_des.str.contains("TOO COLD", na = False)]
#word_too_cold.to_excel(writer, sheet_name = 'TOO COLD')
# Out:
#     WO Number                          Description Building Floor    Room  \
# 41   WO147628                    INCUBATOR - SOUTH     ER-S    02    220S
# 93   WO147609     LIFE SCIENCES - 3105 S. DEARBORN       LS     1     160
# 184  WO146947      IIT RESEARCH TOWER - 10 W. 35TH       IT     8     n/a
# 223  WO146662     LIFE SCIENCES - 3105 S. DEARBORN       LS     1    146D
# 305  WO146731      IIT RESEARCH TOWER - 10 W. 35TH       IT     8     n/a
# 317  WO147013    TECH PARK - SOUTH - 3440 S. STATE       TS     4    4041
# 344  WO147011  LIFE SCIENCES RESEARCH - 35 W. 34TH       LR     0  BB12-1
# 362  WO147002          PERLSTEIN HALL - 10 W. 33RD       PH   n/a     n/a
# 465  WO146940      IIT RESEARCH TOWER - 10 W. 35TH       IT    17     n/a
# 526  WO147718  STUART BUILDING - 10 W. 31ST STREET       SB     0     n/a
# 550  WO146275         FARR HALL - 3300 S. MICHIGAN       FH   n/a     n/a
# 569  WO146723      IIT RESEARCH TOWER - 10 W. 35TH       IT    17     n/a
# ...

# %%
wo[wo_des.str.contains("OVERHEATING", na = False)]
#word_overheating.to_excel(writer, sheet_name = 'OVERHEATING')
# Out:
#     WO Number        Description Building Floor  Room       Craft  \
# 891  WO147138  INCUBATOR - SOUTH     ER-S    02  220S  HVAC EQUIP
#
#                             Description.1          Enter Date      Requestor  \
# 891  URGENT ROOM IS TOO HOT - OVERHEATING 2016-05-20 11:34:02  BARNES, HALEY
#
#     Assigned To  Labor
# 891    JBOOKER2    1.0

# %%
wo[wo_des.str.contains("HEATING", na = False)]
#word_heating.to_excel(writer, sheet_name = 'HEATING')
# Out:
#     WO Number                          Description Building Floor  Room  \
# 276  WO146279           GRADUATE HALL - 70 E. 33RD       GH     1   119
# 325  WO147316  MCCORM. TRIB. C. C. - 3201 S. STATE       MC   n/a   n/a
# 891  WO147138                    INCUBATOR - SOUTH     ER-S    02  220S
# 971  WO147065             COMMONS - 3200 S. WABASH       CO   n/a   n/a
#
#           Craft                                      Description.1  \
# 276    PLUMBING     GH GROUND FLOOR: MEN'S BATHROOM HS NOT HEATING
# 325       OTHER                    SHUT OFF PERIMETER HEATING MTCC
# 891  HVAC EQUIP               URGENT ROOM IS TOO HOT - OVERHEATING
# 971     KITCHEN  COMMONS SOUTH POD: REPAIR FOOD WARMER, NOT HEA...
#
#              Enter Date            Requestor Assigned To  Labor
# 276 2016-05-02 08:46:53  ZAMUDIO, LAURENTINA      SSOLIS   1.75
# 325 2016-05-24 15:13:13       GARZA, VALERIA    TKIRSHNE   1.75
# 891 2016-05-20 11:34:02        BARNES, HALEY    JBOOKER2   1.00
# ...

# %%
wo[wo_des.str.contains("COOLING", na = False)]
# Out:
#     WO Number                          Description Building Floor Room  \
# 1    WO146383          PERLSTEIN HALL - 10 W. 33RD       PH     2  206
# 67   WO147208           CARMEN HALL - 60 EAST 32ND       CH     3  303
# 166  WO147219  MCCORM. TRIB. C. C. - 3201 S. STATE       MC   n/a  n/a
# 191  WO147335         MAIN CAMPUS/ACADEMIC GROUNDS  GROUNDS   n/a  n/a
# 291  WO147266             COMMONS - 3200 S. WABASH       CO   n/a  n/a
# 417  WO147221  MCCORMICK STUDENT VL. 3241 S WABASH       MS   n/a  n/a
# 501  WO146354  MCCORM. TRIB. C. C. - 3201 S. STATE       MC   n/a  n/a
# 630  WO147692             COMMONS - 3200 S. WABASH       CO   n/a  n/a
# 727  WO147334       MACHINERY HALL - 100 WEST 33RD       MH     1  n/a
# 863  WO147298    RETTALIATA ENG CTR - 10 WEST 32ND       E1   n/a  n/a
# 877  WO147595              SOUTH HALL - 71 E. 32ND       SO     4  417
# 897  WO147635            NORTH HALL - 71 EAST 32ND       NH     1  103
#
# ...

# %%
wo[wo_des.str.contains("TEMPERATURE", na = False)]
# Out:
#     WO Number               Description Building Floor Room       Craft  \
# 575  WO146782  COMMONS - 3200 S. WABASH       CO   n/a  n/a  HVAC EQUIP
#
#                                 Description.1          Enter Date  \
# 575  COMMONS: ADJUST TEMPERATURE, REALLY WARM 2016-05-12 08:15:26
#
#           Requestor Assigned To  Labor
# 575  GARZA, VALERIA    TKIRSHNE   0.25

# %%
wo[wo_des.str.contains("CHILLER", na = False)]
# Out:
#     WO Number                       Description    Building Floor    Room  \
# 34   WO146739     LIFE SCIENCE RESEARCH CHILLER  LR-CHILLER    01     n/a
# 235  WO146315     LIFE SCIENCE RESEARCH CHILLER  LR-CHILLER   n/a     n/a
# 260  WO147607   IIT RESEARCH TOWER - 10 W. 35TH          IT    20  20F5-1
# 372  WO146317     LIFE SCIENCE RESEARCH CHILLER  LR-CHILLER   n/a     n/a
# 848  WO146316     LIFE SCIENCE RESEARCH CHILLER  LR-CHILLER   n/a     n/a
# 893  WO147766  MATERIALS TECH.- 3350 S. FEDERAL          MT   n/a     n/a
#
#           Craft                                      Description.1  \
# 34    CUSTODIAL                     CLEAN UP IN CHILLER SHACK ASAP
# 235  HVAC EQUIP        CLEAN SEPERATOR  IN LSR CHILLER SHACK DAILY
# 260  HVAC EQUIP         TAKE CHILLER READINGS  IN IIT TOWER  DAILY
# 372  HVAC EQUIP  TAKE CHILLER READINGS DAILY FOR MONTH OF MAY 2016
# 848  HVAC EQUIP  TAKE CHEMICAL TESTS DAILY  TOWER AND LSR CHILL...
# ...

# %%
wo[wo_des.str.contains("BOILER", na = False)]
# Out:
#     WO Number                          Description Building Floor Room  \
# 120  WO146570  MCCORMICK STUDENT VL. 3241 S WABASH       MS   n/a  n/a
# 332  WO146890  MCCORMICK STUDENT VL. 3241 S WABASH       MS   n/a  n/a
# 409  WO146977  MCCORMICK STUDENT VL. 3241 S WABASH       MS   n/a  n/a
# 530  WO147516  MCCORMICK STUDENT VL. 3241 S WABASH       MS   n/a  n/a
# 820  WO147168  MCCORMICK STUDENT VL. 3241 S WABASH       MS   n/a  n/a
# 961  WO147836  MCCORMICK STUDENT VL. 3241 S WABASH       MS   n/a  n/a
#
#           Craft                       Description.1          Enter Date  \
# 120  MECHANICAL                  BOILER INSPECTIONS 2016-05-06 13:43:39
# 332  MECHANICAL                  BOILER INSPECTIONS 2016-05-13 14:04:21
# 409  HVAC EQUIP  MSV BOILER ROOM REPAIR EXHAUST FAN 2016-05-17 09:04:49
# 530  MECHANICAL                  BOILER INSPECTIONS 2016-05-27 14:20:30
# 820  MECHANICAL                  BOILER INSPECTIONS 2016-05-20 13:15:31
# ...

# %%
wo[wo_des.str.contains("DAMPER", na = False)]
# Out:
#     WO Number                          Description Building Floor Room  \
# 79   WO147230  LIFE SCIENCES RESEARCH - 35 W. 34TH       LR   n/a  n/a
# 386  WO146988       HERMANN HALL - 3241 S. FEDERAL       HH   n/a  n/a
# 455  WO147353                    INCUBATOR - SOUTH     ER-S    01  n/a
# 592  WO147234  LIFE SCIENCES RESEARCH - 35 W. 34TH       LR   n/a  n/a
#
#           Craft                                      Description.1  \
# 79   HVAC EQUIP     CHECK BELTS AND DAMPER ACTUATORS ON LEF-2A, 2B
# 386  HVAC EQUIP                            HH REPAIR MIXED DAMPERS
# 455  HVAC EQUIP  WORK ON EXAUST FAN FOR RO ROOM ERB( OPEN DAMPERS)
# 592  HVAC EQUIP  CHECK BELTS AND DAMPER ACTUATORS ON LEF 2A,2B ...
#
#              Enter Date      Requestor Assigned To  Labor
# 79  2016-05-23 10:13:08  GAUGER, JAMES     DSCOTT4   1.50
# 386 2016-05-17 10:34:27   MUTH, ROBERT       RMUTH   4.75
# 455 2016-05-25 12:48:03  CARMODY, MIKE     NOEHMEN   8.25
# ...

# %%
wo[wo_des.str.contains("STEAM", na = False)]
# Out:
#     WO Number                   Description Building Floor Room       Craft  \
# 406  WO146278  GUNSAULUS - 3140 S. MICHIGAN       GU     9  902  HVAC EQUIP
# 822  WO147403      COMMONS - 3200 S. WABASH       CO     0  n/a       OTHER
# 851  WO146365  GUNSAULUS - 3140 S. MICHIGAN       GU     9  902  HVAC EQUIP
#
#                                          Description.1          Enter Date  \
# 406                                     902 STEAM LEAK 2016-05-02 08:52:37
# 822      LEAKING WATER IN COMMONS NEAR THE STEAM TABLE 2016-05-26 15:13:10
# 851  GUNS ROOM 902 STEAM LEAK - WEEKEND CALL IN ON ... 2016-05-03 13:24:05
#
#             Requestor Assigned To  Labor
# 406     MCMAHON, JOHN     JROGER1   3.75
# 822     SODEXO DINING     RROJAS1   0.75
# 851  DEBRIZZIO, CHUCK    TKIRSHNE   4.25

# %%
wo[wo_des.str.contains("EXHAUST", na = False)]
# Out:
#     WO Number                          Description Building Floor Room  \
# 409  WO146977  MCCORMICK STUDENT VL. 3241 S WABASH       MS   n/a  n/a
# 673  WO146473       HERMANN HALL - 3241 S. FEDERAL       HH     1  n/a
# 730  WO147740       HERMANN HALL - 3241 S. FEDERAL       HH   n/a  n/a
#
#           Craft                              Description.1  \
# 409  HVAC EQUIP         MSV BOILER ROOM REPAIR EXHAUST FAN
# 673  HVAC EQUIP  HH REPLACE EXHAUST FAN IN UNISEX BATHROOM
# 730  HVAC EQUIP       REPAIR WIRING FOR HH KITCHEN EXHAUST
#
#              Enter Date           Requestor Assigned To  Labor
# 409 2016-05-17 09:04:49  STOLLMAYER, JOSEPH    JSTOLLMA   8.00
# 673 2016-05-05 10:49:39        MUTH, ROBERT       RMUTH   1.75
# 730 2016-06-02 13:15:50        CUSACK, MATT       RMUTH  38.50

# %%
wo[wo_des.str.contains("VAB", na = False)]
# Out:
# Empty DataFrame
# Columns: [WO Number, Description, Building, Floor, Room, Craft, Description.1, Enter Date, Requestor, Assigned To, Labor]
# Index: []

# %%
wo[wo_des.str.contains("NOISE", na = False)]
# Out:
#     WO Number                        Description Building Floor    Room  \
# 164  WO147265         CARMEN HALL - 60 EAST 32ND       CH     5     504
# 772  WO147650    IIT RESEARCH TOWER - 10 W. 35TH       IT    20     n/a
# 872  WO147031  STATE STREET VILLAGE - NORTH BLDG       SN     4  NN-4.5
#
#           Craft                                      Description.1  \
# 164  HVAC EQUIP                    CH 504: AC MAKES TOO MUCH NOISE
# 772  HVAC EQUIP                20TH FLOOR TOWER - MECHANICAL NOISE
# 872    PLUMBING  SSV NORTH N 4.5:TOILET MAKES NOISE AND TAKES L...
#
#              Enter Date            Requestor Assigned To  Labor
# 164 2016-05-24 08:34:35  ZAMUDIO, LAURENTINA     FWATSON    1.0
# 772 2016-05-31 13:54:32       SIEGEL, JOSHUA    TJABCZYN    5.0
# 872 2016-05-17 22:03:25  ZAMUDIO, LAURENTINA      MKING8    1.0

# %%
wo[wo_des.str.contains("A/C", na = False)]
# Out:
#     WO Number                     Description Building Floor Room       Craft  \
# 246  WO147633  SIEGEL HALL - 3301 S. DEARBORN       SH     3  309  HVAC EQUIP
# 396  WO147645  SIEGEL HALL - 3301 S. DEARBORN       SH   n/a  n/a  ELECTRICAL
# 705  WO147672  SIEGEL HALL - 3301 S. DEARBORN       SH   n/a  n/a  HVAC EQUIP
# 727  WO147334  MACHINERY HALL - 100 WEST 33RD       MH     1  n/a  HVAC EQUIP
# 949  WO147329     PERLSTEIN HALL - 10 W. 33RD       PH     2  212  HVAC EQUIP
#
#                                          Description.1          Enter Date  \
# 246  SH ROOM 309 A/C NOT WORKING & NEEDED FOR COMPU... 2016-05-31 12:05:30
# 396  CHECK ELECTRIC FOR COMPUTER LAB A/C IN SIEGEL ... 2016-05-31 12:28:36
# 705  (AMI) RENT PORTABLE A/C UNITS FOR SH COMPUTER ... 2016-06-01 09:54:16
# 727                  MH CARPENTER SHOP A/C NOT COOLING 2016-05-25 10:00:06
# 949                         PH 212: NO A/C - NEEDS A/C 2016-05-25 09:23:33
#
#              Requestor Assigned To  Labor
# ...

# %%
wo_it[wo_it_des.str.contains('LOUD', na = False)]
# Out:
#       Wo Number                                        Description  \
# 9024   WO130632                        A/C FAN SUPER LOUD AT 2C8-1
# 10723  WO132342                LIGHT FIXTURE SHAKING LOUDLY-URGENT
# 11731  WO133351  A/C FAN SUPER LOUD AT 2C8-1-REOPEN AGAIN 10.13.15
# 15821  WO137454                        ROOM VENTS/BLOWERS TOO LOUD
# 19880  WO141515  LOUD MACHINE SOUND ABOVE TOWER 19TH FLOOR - WE...
#
#       Assigned To Building Floor   Room       Craft          Enter Date  \
# 9024     TARIANOU       IT     2  2C8-1        HVAC 2015-07-06 12:05:27
# 10723        ECHO       IT    19    n/a  ELECTRICAL 2015-08-11 17:00:58
# 11731    TARIANOU       IT     2  2C8-1  HVAC EQUIP 2015-08-27 11:59:38
# 15821    TJABCZYN       IT     1    n/a  HVAC EQUIP 2015-11-06 07:48:43
# 19880    TARIANOU       IT    19    n/a         NaN 2016-01-29 10:59:58
#
#             Wo Close Date  Hours SUM
# 9024  2015-07-07 14:09:03       2.25
# 10723 2015-08-12 15:59:58       2.00
# ...

# %%
wo_it[wo_it_des.str.contains('RATTL', na = False)]
# Out:
# Empty DataFrame
# Columns: [Wo Number, Description, Assigned To, Building, Floor, Room, Craft, Enter Date, Wo Close Date, Hours SUM]
# Index: []
